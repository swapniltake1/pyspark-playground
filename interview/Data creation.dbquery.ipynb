-- %%
CREATE OR REPLACE TABLE main.default.employees (
  emp_id INT,
  name STRING,
  role STRING,
  dept_code STRING,
  hire_date DATE,
  salary DOUBLE,
  email STRING,
  last_updated TIMESTAMP
)
USING DELTA
COMMENT 'Employee dummy data for practice';

INSERT INTO main.default.employees VALUES
  (101, 'Swapnil Take', 'Data Engineer', 'IT', '2024-01-15', 95000.00, 'swapnil@example.com', current_timestamp()),
  (102, 'Anjali Sharma', 'Java Developer', 'HR', '2023-11-20', 82000.00, 'anjali@example.com', current_timestamp()),
  (103, 'Rahul Patil', 'QA Automation', 'IT', '2024-02-10', 75000.50, 'rahul@example.com', current_timestamp()),
  (104, 'Priya Verma', 'Cloud Architect', 'INFRA', '2022-05-30', 120000.00, 'priya@example.com', current_timestamp()),
  (105, 'Amit Deshmukh', 'Data Analyst', 'BI', '2024-01-05', 68000.00, 'amit@example.com', current_timestamp());
