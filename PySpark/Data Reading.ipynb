# %% [markdown]
# #### Data Reading

# %%
dbutils.fs.ls('/FileStore/tables')

# %%
df = spark.read.format('csv').option('inferSchema','true').option('header','true').load('/Volumes/raw-data/git/allfiles/BigMart Sales.csv')

# %%
df.display()
